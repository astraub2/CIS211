# %% [markdown]
# # <span style="color:teal;">CIS 211 Project 7:  SQLite</span>

# %% [markdown]
# ##### Due 11:00 P.M. Friday Feb 26

# %% [markdown]
# This project will give you some experience writing database queries in SQL and connecting to a SQLite database from Python.

# %% [markdown]
# ### <span style="color:teal">Setup</span>

# %% [markdown]
# Download the Sakila database (the file named `sakila211.db`) and move it to the same folder as this IPython notebook.

# %% [markdown]
# ### <span style="color:teal">Executing Queries in an IPython Notebook</span>

# %% [markdown]
# To solve the problems in the first two sections of this project you need to write a SQL query based on the tables in the Sakila211 database.
#
# To execute a query from an IPython Notebook write the query in quotes as part of a shell command:
# ```
# ! sqlite3 sakila211.db "..."
# ```
#
# For example, to answer the question "What are the names and ratings of the films" your code cell would have
# ```
# ! sqlite3 sakila211.db "select title, rating from film"
# ```
#
# Some of the queries will produce a lot of output.  You can add a `LIMIT` clause to any query if you want to reduce the size of the output.

# %% [markdown]
# **Note:** &nbsp; Your grade will not depend on the output format.  If want to have a nicer looking output that includes column headers create a file named `.sqliterc` in your home folder and add these two lines:
# ```
# .header on
# .mode column
# ```

# %% [markdown]
# ## <span style="color:teal">Part 1:  &nbsp; Queries</span>

# %% [markdown]
# The following questions can all be answered using records from a single table.

# %% [markdown]
# (1) What are the first and last names of all the customers?

# %%
! sqlite3 sakila211.db "select first_name, last_name from customer"
# Out:
# Mary|Smith
# Patricia|Johnson
# Linda|Williams
# Barbara|Jones
# Elizabeth|Brown
# Jennifer|Davis
# Maria|Miller
# Susan|Wilson
# Margaret|Moore
# Dorothy|Taylor
# Lisa|Anderson
# Nancy|Thomas
# Karen|Jackson
# Betty|White
# Helen|Harris
# Sandra|Martin
# Donna|Thompson
# Carol|Garcia
# Ruth|Martinez
# Sharon|Robinson
# Michelle|Clark
# Laura|Rodriguez
# Sarah|Lewis
# Kimberly|Lee
# Deborah|Walker
# Jessica|Hall
# Shirley|Allen
# Cynthia|Young
# Angela|Hernandez
# Melissa|King
# Brenda|Wright
# Amy|Lopez
# Anna|Hill
# Rebecca|Scott
# Virginia|Green
# Kathleen|Adams
# Pamela|Baker
# Martha|Gonzalez
# Debra|Nelson
# Amanda|Carter
# Stephanie|Mitchell
# Carolyn|Perez
# Christine|Roberts
# Marie|Turner
# Janet|Phillips
# Catherine|Campbell
# Frances|Parker
# Ann|Evans
# Joyce|Edwards
# Diane|Collins
# Alice|Stewart
# Julie|Sanchez
# Heather|Morris
# Teresa|Rogers
# Doris|Reed
# Gloria|Cook
# Evelyn|Morgan
# Jean|Bell
# Cheryl|Murphy
# Mildred|Bailey
# Katherine|Rivera
# Joan|Cooper
# Ashley|Richardson
# Judith|Cox
# Rose|Howard
# Janice|Ward
# Kelly|Torres
# Nicole|Peterson
# Judy|Gray
# Christina|Ramirez
# Kathy|James
# Theresa|Watson
# Beverly|Brooks
# Denise|Kelly
# Tammy|Sanders
# Irene|Price
# Jane|Bennett
# Lori|Wood
# Rachel|Barnes
# Marilyn|Ross
# Andrea|Henderson
# Kathryn|Coleman
# Louise|Jenkins
# Howard|Fortner
# Eugene|Culpepper
# Carlos|Coughlin
# Russell|Brinson
# Bobby|Boudreau
# Victor|Barkley
# Martin|Bales
# Ernest|Stepp
# Phillip|Holm
# Todd|Tan
# Jesse|Schilling
# Craig|Morrell
# Alan|Kahn
# Shawn|Heaton
# Clarence|Gamez
# Sean|Douglass
# Philip|Causey
# Chris|Brothers
# Johnny|Turpin
# Earl|Shanks
# Jimmy|Schrader
# Antonio|Meek
# Danny|Isom
# Bryan|Hardison
# Tony|Carranza
# Luis|Yanez
# Mike|Way
# Stanley|Scroggins
# Leonard|Schofield
# Nathan|Runyon
# Dale|Ratcliff
# Manuel|Murrell
# Rodney|Moeller
# Curtis|Irby
# Norman|Currier
# Allen|Butterfield
# Marvin|Yee
# Vincent|Ralston
# Glenn|Pullen
# Jeffery|Pinson
# Travis|Estep
# Jeff|East
# Chad|Carbone
# Jacob|Lance
# Lee|Hawks
# Melvin|Ellington
# Alfred|Casillas
# Kyle|Spurlock
# Francis|Sikes
# Bradley|Motley
# Jesus|Mccartney
# Herbert|Kruger
# Frederick|Isbell
# Ray|Houle
# Joel|Francisco
# Edwin|Burk
# Don|Bone
# Eddie|Tomlin
# Ricky|Shelby
# Troy|Quigley
# Randall|Neumann
# Barry|Lovelace
# Alexander|Fennell
# Bernard|Colby
# Mario|Cheatham
# Leroy|Bustamante
# Francisco|Skidmore
# Marcus|Hidalgo
# Micheal|Forman
# Theodore|Culp
# Clifford|Bowens
# Miguel|Betancourt
# Oscar|Aquino
# Jay|Robb
# Jim|Rea
# Tom|Milner
# Calvin|Martel
# Alex|Gresham
# Jon|Wiles
# Ronnie|Ricketts
# Bill|Gavin
# Lloyd|Dowd
# Tommy|Collazo
# Leon|Bostic
# Derek|Blakely
# Warren|Sherrod
# Darrell|Power
# Jerome|Kenyon
# Floyd|Gandy
# Leo|Ebert
# Alvin|Deloach
# Tim|Cary
# Wesley|Bull
# Gordon|Allard
# Dean|Sauer
# Greg|Robins
# Jorge|Olivares
# Dustin|Gillette
# Pedro|Chestnut
# Derrick|Bourque
# Dan|Paine
# Lewis|Lyman
# Zachary|Hite
# Corey|Hauser
# Herman|Devore
# Maurice|Crawley
# Vernon|Chapa
# Roberto|Vu
# Clyde|Tobias
# Glen|Talbert
# Hector|Poindexter
# Shane|Millard
# Ricardo|Meador
# Sam|Mcduffie
# Rick|Mattox
# Lester|Kraus
# Brent|Harkins
# Ramon|Choate
# Charlie|Bess
# Tyler|Wren
# Gilbert|Sledge
# Gene|Sanborn
# Marc|Outlaw
# Reginald|Kinder
# Ruben|Geary
# Brett|Cornwell
# Angel|Barclay
# Nathaniel|Adam
# Rafael|Abney
# Leslie|Seward
# Edgar|Rhoads
# Milton|Howland
# Raul|Fortier
# Ben|Easter
# Chester|Benner
# Cecil|Vines
# Duane|Tubbs
# Franklin|Troutman
# Andre|Rapp
# Elmer|Noe
# Brad|Mccurdy
# Gabriel|Harder
# Ron|Deluca
# Mitchell|Westmoreland
# Roland|South
# Arnold|Havens
# Harvey|Guajardo
# Jared|Ely
# Adrian|Clary
# Karl|Seal
# Cory|Meehan
# Claude|Herzog
# Erik|Guillen
# Darryl|Ashcraft
# Jamie|Waugh
# Neil|Renner
# Jessie|Milam
# Christian|Jung
# Javier|Elrod
# Fernando|Churchill
# Clinton|Buford
# Ted|Breaux
# Mathew|Bolin
# Tyrone|Asher
# Darren|Windham
# Lonnie|Tirado
# Lance|Pemberton
# Cody|Nolen
# Julio|Noland
# Kelly|Knott
# Kurt|Emmons
# Allan|Cornish
# Nelson|Christenson
# Guy|Brownlee
# Clayton|Barbee
# Hugh|Waldrop
# Max|Pitt
# Dwayne|Olvera
# Dwight|Lombardi
# Armando|Gruber
# Felix|Gaffney
# Jimmie|Eggleston
# Everett|Banda
# Jordan|Archuleta
# Ian|Still
# Wallace|Slone
# Ken|Prewitt
# Bob|Pfeiffer
# Jaime|Nettles
# Casey|Mena
# Alfredo|Mcadams
# Alberto|Henning
# Dave|Gardiner
# Ivan|Cromwell
# Johnnie|Chisholm
# Sidney|Burleson
# Byron|Box
# Julian|Vest
# Isaac|Oglesby
# Morris|Mccarter
# Clifton|Malcolm
# Willard|Lumpkin
# Daryl|Larue
# Ross|Grey
# Virgil|Wofford
# Andy|Vanhorn
# Marshall|Thorn
# Salvador|Teel
# Perry|Swafford
# Kirk|Stclair
# Sergio|Stanfield
# Marion|Ocampo
# Tracy|Herrmann
# Seth|Hannon
# Kent|Arsenault
# Terrance|Roush
# Rene|Mcalister
# Eduardo|Hiatt
# Terrence|Gunderson
# Enrique|Forsythe
# Freddie|Duggan
# Wade|Delvalle
# Austin|Cintron

# %% [markdown]
# (2) What are the e-mail addresses of customers whose first name is “Willard”?

# %%
! sqlite3 sakila211.db "select first_name, email from customer where first_name='Willard'"
# Out:
# Willard|willard.lumpkin@sakilacustomer.org

# %% [markdown]
# (3) How many customers are there?

# %%
! sqlite3 sakila211.db "select count() from customer"
# Out:
# 599

# %% [markdown]
# (4) How many customers shop at store number 1?

# %%
! sqlite3 sakila211.db "select count() from customer where store_id=1"
# Out:
# 326

# %% [markdown]
# (5) How much does it cost to rent the film named “Virtual Spoilers”?

# %%
! sqlite3 sakila211.db "select rental_rate from film where title='Virtual Spoilers'"
# Out:
# 4.99

# %% [markdown]
# (6) Do any films have the word “Princess” in the title?

# %%
! sqlite3 sakila211.db "select title from film where title like '%Princess%' "
# Out:
# Image Princess
# Princess Giant

# %% [markdown]
# (7) What are the titles of the films that are longer than 180 minutes?

# %%
! sqlite3 sakila211.db "select title, length from film where length>80 "
# Out:
# Academy Dinosaur|86
# Affair Prejudice|117
# African Egg|130
# Agent Truman|169
# Alabama Devil|114
# Alamo Videotape|126
# Alaska Phantom|136
# Ali Forever|150
# Alice Fantasia|94
# Alley Evolution|180
# Alone Trip|82
# Amadeus Holy|113
# American Circus|129
# Amistad Midsummer|85
# Anaconda Confessions|92
# Analyze Hoosiers|181
# Annie Identity|86
# Anonymous Human|179
# Anthem Luke|91
# Antitrust Tomatoes|168
# Anything Savannah|82
# Undefeated Dalmations|107
# Unforgiven Zoolander|129
# United Pilot|164
# Untouchables Sunrise|120
# Uprising Uptown|174
# Uptown Young|84
# Usual Untouchables|128
# Vacation Boondock|145
# Vampire Whale|126
# Vanilla Day|122
# Vanished Garden|142
# Vanishing Rocky|123
# Varsity Trip|85
# Velvet Terminator|173
# Vertigo Northwest|90
# Videotape Arsenic|145
# Vietnam Smoochy|174
# Virgin Daisy|179
# Virginian Pluto|164
# Virtual Spoilers|144
# Voice Peach|139
# Volcano Texas|157
# Volume House|132
# Wagon Jaws|152
# Wait Cider|112
# Walls Artist|135
# Wanda Chamber|107
# Wardrobe Phantom|178
# Warlock Werewolf|83
# Wars Pluto|128
# Wash Heavenly|161
# Wasteland Divine|85
# Watership Frontier|112
# Weekend Personal|134
# West Lion|159
# Whale Bikini|109
# Wife Turn|183
# Wild Apollo|181
# Willow Tracy|137
# Wind Phantom|111
# Window Side|85
# Wisdom Worker|98
# Witches Panic|100
# Women Dorado|126
# Won Dares|105
# Wonderful Drop|126
# Wonderland Christmas|111
# Wonka Sea|85
# Words Hunter|116
# Worker Tarzan|139
# World Leathernecks|171
# Worst Banger|185
# Wrath Mile|176
# Wrong Behavior|178
# Wyoming Storm|100
# Yentl Idaho|86
# Young Language|183
# Youth Kick|179
# Zhivago Core|105
# Zoolander Fiction|101

# %% [markdown]
# (8) How many films have a “G” rating and are less than 60 minutes long?

# %%
! sqlite3 sakila211.db "select count() from film where rating='G' and length<60"
# Out:
# 21

# %% [markdown]
# (9) What is the maximum replacement cost for any film?

# %%
! sqlite3 sakila211.db "select max(replacement_cost) from film"
# Out:
# 29.99

# %% [markdown]
# (10) Print a table that lists the different types of ratings and the number of films that have that rating.

# %%
! sqlite3 sakila211.db "select rating, count() from film  group by rating"
# Out:
# G|178
# NC-17|210
# PG|194
# PG-13|223
# R|195

# %% [markdown]
# ## <span style="color:teal">Part 2: &nbsp; Joins</span>

# %% [markdown]
# The following queries all require a join of two or more tables. As a hint for how to create the query the table names are shown next to each a question.

# %% [markdown]
# (11) What are the film IDs of movies starring Jude Cruise?  &nbsp; &nbsp; [`actor`, `film_actor`]

# %%
! sqlite3 sakila211.db "select film_id from actor join film_actor using (actor_id) where actor.first_name='Jude' and actor.last_name='Cruise'"
# Out:
# 16
# 34
# 101
# 114
# 122
# 134
# 144
# 153
# 192
# 213
# 258
# 267
# 317
# 340
# 393
# 437
# 447
# 502
# 592
# 605
# 637
# 685
# 707
# 714
# 717
# 737
# 767
# 852
# 891
# 918

# %% [markdown]
# (12) What language was “Ace Goldfinger” filmed in?  &nbsp; &nbsp; [`film`, `language`]

# %%
! sqlite3 sakila211.db "select name from film join language using (language_id) where film.title='Ace Goldfinger'"
# Out:
# Japanese

# %% [markdown]
# (13) How many actors starred in the film named “Scalawag Duck”? &nbsp; &nbsp; [`film`, `film_actor`]

# %%
! sqlite3 sakila211.db "select count() from film join film_actor using (film_id) where film.title= 'Scalawag Duck'"
# Out:
# 5

# %% [markdown]
# (14) Produce a table that shows how many films each customer has rented.  &nbsp; &nbsp; [`customer`, `rental`]

# %%
! sqlite3 sakila211.db "select first_name, last_name, count() from customer join rental using (customer_id) group by customer_id"
# Out:
# Mary|Smith|32
# Patricia|Johnson|27
# Linda|Williams|26
# Barbara|Jones|22
# Elizabeth|Brown|38
# Jennifer|Davis|28
# Maria|Miller|33
# Susan|Wilson|24
# Margaret|Moore|23
# Dorothy|Taylor|25
# Lisa|Anderson|24
# Nancy|Thomas|28
# Karen|Jackson|27
# Betty|White|28
# Helen|Harris|32
# Sandra|Martin|28
# Donna|Thompson|21
# Carol|Garcia|22
# Ruth|Martinez|24
# Sharon|Robinson|30
# Michelle|Clark|35
# Laura|Rodriguez|22
# Sarah|Lewis|30
# Kimberly|Lee|25
# Deborah|Walker|29
# Jessica|Hall|34
# Shirley|Allen|31
# Cynthia|Young|32
# Angela|Hernandez|36
# Melissa|King|34
# Brenda|Wright|26
# Amy|Lopez|29
# Anna|Hill|21
# Rebecca|Scott|24
# Virginia|Green|32
# Kathleen|Adams|27
# Pamela|Baker|23
# Martha|Gonzalez|34
# Debra|Nelson|29
# Amanda|Carter|27
# Stephanie|Mitchell|25
# Carolyn|Perez|30
# Christine|Roberts|24
# Marie|Turner|26
# Janet|Phillips|27
# Catherine|Campbell|34
# Frances|Parker|22
# Ann|Evans|17
# Joyce|Edwards|28
# Diane|Collins|35
# Alice|Stewart|33
# Julie|Sanchez|29
# Heather|Morris|30
# Teresa|Rogers|29
# Doris|Reed|22
# Gloria|Cook|30
# Evelyn|Morgan|28
# Jean|Bell|27
# Cheryl|Murphy|27
# Mildred|Bailey|25
# Katherine|Rivera|14
# Joan|Cooper|23
# Ashley|Richardson|25
# Judith|Cox|33
# Rose|Howard|22
# Janice|Ward|34
# Kelly|Torres|22
# Nicole|Peterson|22
# Judy|Gray|25
# Christina|Ramirez|18
# Kathy|James|30
# Theresa|Watson|30
# Beverly|Brooks|24
# Denise|Kelly|27
# Tammy|Sanders|41
# Irene|Price|23
# Jane|Bennett|28
# Lori|Wood|31
# Rachel|Barnes|22
# Marilyn|Ross|30
# Andrea|Henderson|22
# Kathryn|Coleman|26
# Louise|Jenkins|25
# Sara|Perry|33
# Anne|Powell|23
# Jacqueline|Long|33
# Wanda|Patterson|30
# Bonnie|Hughes|21
# Julia|Flores|32
# Ruby|Washington|28
# Lois|Butler|35
# Tina|Simmons|28
# Phyllis|Foster|23
# Norma|Gonzales|21
# Paula|Bryant|18
# Diana|Alexander|27
# Annie|Russell|18
# Lillian|Griffin|25
# Emily|Diaz|24
# Robin|Hayes|24
# Peggy|Myers|24
# Crystal|Ford|33
# Gladys|Hamilton|31
# Rita|Graham|24
# Dawn|Sullivan|26
# Connie|Wallace|23
# Florence|Woods|30
# Tracy|Cole|30
# Edna|West|26
# Tiffany|Jordan|14
# Carmen|Owens|26
# Rosa|Reynolds|30
# Cindy|Fisher|29
# Grace|Ellis|33
# Wendy|Harrison|30
# Victoria|Gibson|27
# Edith|Mcdonald|19
# Kim|Cruz|21
# Heidi|Larson|34
# Glenda|Frazier|32
# Lydia|Burke|24
# Viola|Hanson|32
# Courtney|Day|32
# Marian|Mendoza|23
# Stella|Moreno|22
# Caroline|Bowman|15
# Dora|Medina|23
# Jo|Fowler|20
# Vickie|Brewer|31
# Mattie|Hoffman|22
# Terry|Carlson|29
# Maxine|Silva|32
# Irma|Pearson|18
# Mabel|Holland|30
# Marsha|Douglas|37
# Myrtle|Fleming|24
# Lena|Jensen|32
# Christy|Vargas|31
# Deanna|Byrd|26
# Patsy|Davidson|28
# Hilda|Hopkins|29
# Gwendolyn|May|25
# Jennie|Terry|29
# Nora|Herrera|28
# Margie|Wade|36
# Nina|Soto|29
# Cassandra|Walters|30
# Leah|Curtis|25
# Penny|Neal|18
# Kay|Caldwell|20
# Priscilla|Lowe|35
# Naomi|Jennings|35
# Carole|Barnett|30
# Brandy|Graves|28
# Olga|Jimenez|32
# Billie|Horton|26
# Dianne|Shelton|31
# Tracey|Barrett|27
# Leona|Obrien|14
# Jenny|Castro|27
# Felicia|Sutton|28
# Sonia|Gregory|28
# Miriam|Mckinney|26
# Velma|Lucas|27
# Becky|Miles|29
# Bobbie|Craig|24
# Violet|Rodriquez|30
# Kristina|Chambers|28
# Toni|Holt|23
# Misty|Lambert|27
# Mae|Fletcher|31
# Shelly|Watts|26
# Daisy|Bates|38
# Ramona|Hale|30
# Sherri|Rhodes|33
# Erika|Pena|26
# James|Gannon|30
# John|Farnsworth|31
# Robert|Baughman|21
# Michael|Silverman|29
# William|Satterfield|26
# David|Royal|26
# Richard|Mccrary|25
# Charles|Kowalski|32
# Joseph|Joy|30
# Thomas|Grigsby|25
# Christopher|Greco|31
# Daniel|Cabral|20
# Paul|Trout|23
# Mark|Rinehart|26
# Donald|Mahon|23
# George|Linton|33
# Kenneth|Gooden|17
# Steven|Curley|29
# Edward|Baugh|28
# Brian|Wyman|12
# Ronald|Weiner|30
# Anthony|Schwab|20
# Kevin|Schuler|22
# Jason|Morrissey|28
# Matthew|Mahan|31
# Gary|Coy|25
# Timothy|Bunn|22
# Jose|Andrew|25
# Larry|Thrasher|26
# Jeffrey|Spear|23
# Frank|Waggoner|32
# Scott|Shelley|25
# Eric|Robert|27
# Stephen|Qualls|28
# Andrew|Purdy|27
# Raymond|Mcwhorter|30
# Gregory|Mauldin|23
# Joshua|Mark|30
# Jerry|Jordon|29
# Dennis|Gilman|28
# Walter|Perryman|30
# Patrick|Newsom|31
# Peter|Menard|23
# Harold|Martino|32
# Douglas|Graf|25
# Henry|Billingsley|18
# Carl|Artis|23
# Arthur|Simpkins|32
# Ryan|Salisbury|30
# Roger|Quintanilla|36
# Joe|Gilliland|29
# Juan|Fraley|23
# Jack|Foust|24
# Albert|Crouse|23
# Jonathan|Scarborough|18
# Justin|Ngo|36
# Terry|Grissom|20
# Gerald|Fultz|30
# Keith|Rico|26
# Samuel|Marlow|21
# Willie|Markham|25
# Ralph|Madrigal|34
# Lawrence|Lawton|31
# Nicholas|Barfield|32
# Roy|Whiting|29
# Benjamin|Varney|23
# Bruce|Schwarz|23
# Brandon|Huey|37
# Adam|Gooch|22
# Harry|Arce|35
# Fred|Wheat|25
# Wayne|Truong|19
# Billy|Poulin|35
# Steve|Mackenzie|34
# Louis|Leone|35
# Jeremy|Hurtado|28
# Aaron|Selby|24
# Randy|Gaither|28
# Howard|Fortner|26
# Eugene|Culpepper|19
# Carlos|Coughlin|23
# Russell|Brinson|36
# Bobby|Boudreau|35
# Victor|Barkley|24
# Martin|Bales|27
# Ernest|Stepp|25
# Phillip|Holm|26
# Todd|Tan|29
# Jesse|Schilling|26
# Craig|Morrell|30
# Alan|Kahn|26
# Shawn|Heaton|33
# Clarence|Gamez|30
# Sean|Douglass|23
# Philip|Causey|31
# Chris|Brothers|22
# Johnny|Turpin|19
# Earl|Shanks|27
# Jimmy|Schrader|29
# Antonio|Meek|16
# Danny|Isom|21
# Bryan|Hardison|28
# Tony|Carranza|21
# Luis|Yanez|20
# Mike|Way|35
# Stanley|Scroggins|30
# Leonard|Schofield|32
# Nathan|Runyon|32
# Dale|Ratcliff|27
# Manuel|Murrell|30
# Rodney|Moeller|23
# Curtis|Irby|38
# Norman|Currier|26
# Allen|Butterfield|21
# Marvin|Yee|21
# Vincent|Ralston|25
# Glenn|Pullen|23
# Jeffery|Pinson|31
# Travis|Estep|25
# Jeff|East|30
# Chad|Carbone|25
# Jacob|Lance|21
# Lee|Hawks|27
# Melvin|Ellington|26
# Alfred|Casillas|26
# Kyle|Spurlock|30
# Francis|Sikes|26
# Bradley|Motley|27
# Jesus|Mccartney|24
# Herbert|Kruger|20
# Frederick|Isbell|21
# Ray|Houle|22
# Joel|Francisco|23
# Edwin|Burk|23
# Don|Bone|25
# Eddie|Tomlin|27
# Ricky|Shelby|25
# Troy|Quigley|30
# Randall|Neumann|23
# Barry|Lovelace|33
# Alexander|Fennell|36
# Bernard|Colby|22
# Mario|Cheatham|28
# Leroy|Bustamante|32
# Francisco|Skidmore|22
# Marcus|Hidalgo|30
# Micheal|Forman|26
# Theodore|Culp|31
# Clifford|Bowens|29
# Miguel|Betancourt|29
# Oscar|Aquino|20
# Jay|Robb|26
# Jim|Rea|33
# Tom|Milner|32
# Calvin|Martel|23
# Alex|Gresham|33
# Jon|Wiles|24
# Ronnie|Ricketts|25
# Bill|Gavin|28
# Lloyd|Dowd|19
# Tommy|Collazo|38
# Leon|Bostic|25
# Derek|Blakely|28
# Warren|Sherrod|33
# Darrell|Power|25
# Jerome|Kenyon|16
# Floyd|Gandy|17
# Leo|Ebert|23
# Alvin|Deloach|29
# Tim|Cary|39
# Wesley|Bull|40
# Gordon|Allard|32
# Dean|Sauer|27
# Greg|Robins|30
# Jorge|Olivares|34
# Dustin|Gillette|26
# Pedro|Chestnut|24
# Derrick|Bourque|22
# Dan|Paine|22
# Lewis|Lyman|19
# Zachary|Hite|31
# Corey|Hauser|22
# Herman|Devore|29
# Maurice|Crawley|29
# Vernon|Chapa|18
# Roberto|Vu|30
# Clyde|Tobias|29
# Glen|Talbert|26
# Hector|Poindexter|26
# Shane|Millard|22
# Ricardo|Meador|21
# Sam|Mcduffie|24
# Rick|Mattox|27
# Lester|Kraus|16
# Brent|Harkins|23
# Ramon|Choate|31
# Charlie|Bess|26
# Tyler|Wren|21
# Gilbert|Sledge|28
# Gene|Sanborn|27
# Marc|Outlaw|30
# Reginald|Kinder|28
# Ruben|Geary|21
# Brett|Cornwell|34
# Angel|Barclay|32
# Nathaniel|Adam|28
# Rafael|Abney|21
# Leslie|Seward|35
# Edgar|Rhoads|25
# Milton|Howland|25
# Raul|Fortier|20
# Ben|Easter|26
# Chester|Benner|24
# Cecil|Vines|26
# Duane|Tubbs|31
# Franklin|Troutman|22
# Andre|Rapp|28
# Elmer|Noe|26
# Brad|Mccurdy|25
# Gabriel|Harder|26
# Ron|Deluca|23
# Mitchell|Westmoreland|32
# Roland|South|23
# Arnold|Havens|33
# Harvey|Guajardo|22
# Jared|Ely|19
# Adrian|Clary|19
# Karl|Seal|45
# Cory|Meehan|24
# Claude|Herzog|25
# Erik|Guillen|29
# Darryl|Ashcraft|23
# Jamie|Waugh|25
# Neil|Renner|32
# Jessie|Milam|33
# Christian|Jung|24
# Javier|Elrod|32
# Fernando|Churchill|25
# Clinton|Buford|25
# Ted|Breaux|29
# Mathew|Bolin|22
# Tyrone|Asher|24
# Darren|Windham|24
# Lonnie|Tirado|18
# Lance|Pemberton|22
# Cody|Nolen|22
# Julio|Noland|21
# Kelly|Knott|25
# Kurt|Emmons|23
# Allan|Cornish|19
# Nelson|Christenson|20
# Guy|Brownlee|32
# Clayton|Barbee|26
# Hugh|Waldrop|21
# Max|Pitt|24
# Dwayne|Olvera|22
# Dwight|Lombardi|17
# Armando|Gruber|21
# Felix|Gaffney|24
# Jimmie|Eggleston|28
# Everett|Banda|28
# Jordan|Archuleta|30
# Ian|Still|27
# Wallace|Slone|25
# Ken|Prewitt|29
# Bob|Pfeiffer|24
# Jaime|Nettles|29
# Casey|Mena|34
# Alfredo|Mcadams|20
# Alberto|Henning|21
# Dave|Gardiner|32
# Ivan|Cromwell|26
# Johnnie|Chisholm|24
# Sidney|Burleson|25
# Byron|Box|29
# Julian|Vest|28
# Isaac|Oglesby|29
# Morris|Mccarter|34
# Clifton|Malcolm|27
# Willard|Lumpkin|22
# Daryl|Larue|27
# Ross|Grey|27
# Virgil|Wofford|27
# Andy|Vanhorn|25
# Marshall|Thorn|23
# Salvador|Teel|30
# Perry|Swafford|24
# Kirk|Stclair|19
# Sergio|Stanfield|26
# Marion|Ocampo|29
# Tracy|Herrmann|28
# Seth|Hannon|25
# Kent|Arsenault|27
# Terrance|Roush|29
# Rene|Mcalister|26
# Eduardo|Hiatt|27
# Terrence|Gunderson|30
# Enrique|Forsythe|28
# Freddie|Duggan|25
# Wade|Delvalle|22
# Austin|Cintron|19

# %% [markdown]
# (15) How many films did the customer named Smith rent?  &nbsp; &nbsp; [`customer`, `rental`]

# %%
! sqlite3 sakila211.db "select count() from customer join rental using (customer_id) where first_name='Smith' or last_name='Smith'
# Out:
# 32

# %% [markdown]
# (16) Which customers have not returned films (*i.e.* the return_date field in the rental table is null)?  &nbsp; &nbsp; [`customer`, `rental`]

# %%
! sqlite3 sakila211.db "select first_name, last_name from customer join rental using (customer_id) where return_date is NULL"
# Out:
# Gail|Knight
# Gregory|Mauldin
# Louise|Jenkins
# Willie|Howell
# Emily|Diaz
# Laurie|Lawrence
# Lisa|Anderson
# Freddie|Duggan
# Heather|Morris
# Roland|South
# Natalie|Meyer
# Scott|Shelley
# Louis|Leone
# Cathy|Spencer
# Guy|Brownlee
# Justin|Ngo
# Jerry|Jordon
# Alicia|Mills
# Jeanne|Lawson
# Dustin|Gillette
# Morris|Mccarter
# Judy|Gray
# Julie|Sanchez
# Ramona|Hale
# Sonia|Gregory
# Margie|Wade
# Zachary|Hite
# Jordan|Archuleta
# Andy|Vanhorn
# Elmer|Noe
# Peggy|Myers
# Sergio|Stanfield
# Laura|Rodriguez
# Anna|Hill
# Gail|Knight
# Marilyn|Ross
# Mildred|Bailey
# Grace|Ellis
# Barry|Lovelace
# Edward|Baugh
# Cassandra|Walters
# Bill|Gavin
# Curtis|Irby
# Allison|Stanley
# Courtney|Day
# Gilbert|Sledge
# Ivan|Cromwell
# Wanda|Patterson
# Viola|Hanson
# Stacey|Montgomery
# Justin|Ngo
# Cecil|Vines
# Leonard|Schofield
# Craig|Morrell
# Marion|Snyder
# Stacy|Cunningham
# Lois|Butler
# Elmer|Noe
# Cynthia|Young
# Sonia|Gregory
# Natalie|Meyer
# Marcia|Dean
# Ana|Bradley
# Joshua|Mark
# Cassandra|Walters
# Wendy|Harrison
# Florence|Woods
# Bernard|Colby
# Beverly|Brooks
# Annette|Olson
# Chris|Brothers
# Tyler|Wren
# Elizabeth|Brown
# Norman|Currier
# Travis|Estep
# Tamara|Nguyen
# Lawrence|Lawton
# Judith|Cox
# Carolyn|Perez
# Colleen|Burton
# Juanita|Mason
# Clinton|Buford
# Brandon|Huey
# Marie|Turner
# Morris|Mccarter
# Naomi|Jennings
# Tammy|Sanders
# Dianne|Shelton
# Darryl|Ashcraft
# Miguel|Betancourt
# Albert|Crouse
# Allan|Cornish
# Joel|Francisco
# Margie|Wade
# Lucy|Wheeler
# Charlie|Bess
# Mattie|Hoffman
# Betty|White
# Helen|Harris
# Fred|Wheat
# Derrick|Bourque
# Beth|Franklin
# Gary|Coy
# Helen|Harris
# Jessie|Milam
# Annette|Olson
# Dwayne|Olvera
# Vickie|Brewer
# Heather|Morris
# Brent|Harkins
# Jay|Robb
# Tom|Milner
# Becky|Miles
# Holly|Fox
# Raymond|Mcwhorter
# Lauren|Hudson
# Gwendolyn|May
# Cory|Meehan
# Felix|Gaffney
# Milton|Howland
# Jeanette|Greene
# Gina|Williamson
# Ian|Still
# Jordan|Archuleta
# Kenneth|Gooden
# Tammy|Sanders
# Melanie|Armstrong
# Bill|Gavin
# Christian|Jung
# Alberto|Henning
# Perry|Swafford
# Terrance|Roush
# Neil|Renner
# Miguel|Betancourt
# Mildred|Bailey
# Terry|Grissom
# Lawrence|Lawton
# Mario|Cheatham
# Joe|Gilliland
# Greg|Robins
# Michelle|Clark
# Adrian|Clary
# Robin|Hayes
# Kyle|Spurlock
# Yolanda|Weaver
# Tammy|Sanders
# Allison|Stanley
# Cathy|Spencer
# Hilda|Hopkins
# Tracy|Cole
# Larry|Thrasher
# Allen|Butterfield
# Jean|Bell
# Norma|Gonzales
# Carolyn|Perez
# Enrique|Forsythe
# Jenny|Castro
# Melvin|Ellington
# April|Burns
# Seth|Hannon
# Florence|Woods
# Sarah|Lewis
# Carmen|Owens
# Angela|Hernandez
# Christine|Roberts
# Kristin|Johnston
# Willie|Markham
# John|Farnsworth
# Lee|Hawks
# Gloria|Cook
# Lucy|Wheeler
# Katie|Elliott
# Daisy|Bates
# Christine|Roberts
# Claudia|Fuller
# Sylvia|Ortiz
# Daryl|Larue
# Margaret|Moore
# Jessie|Banks
# Rafael|Abney
# Stephanie|Mitchell
# Regina|Berry
# Jeremy|Hurtado

# %% [markdown]
# (17) Which actors starred in “Splash Gump”?  &nbsp; &nbsp; [`film`, `film_actor`, `actor`]

# %%
! sqlite3 sakila211.db "select first_name, last_name from actor join film_actor using(actor_id) join film using (film_id) where film.title='Splash Gump'"
# Out:
# Penelope|Guiness
# Jennifer|Davis
# Uma|Wood
# Cameron|Streep
# Christian|Neeson
# Ray|Johansson
# Gene|Willis
# Morgan|Williams
# Humphrey|Willis
# Al|Garland

# %% [markdown]
# (18) Which films has Penelope Guiness starred in?  &nbsp; &nbsp; [`film`, `film_actor`, `actor`]

# %%
! sqlite3 sakila211.db "select title from actor join film_actor using(actor_id) join film using (film_id) where actor.first_name='Penelope' and actor.last_name='Guiness'"
# Out:
# Academy Dinosaur
# Anaconda Confessions
# Angels Life
# Bulworth Commandments
# Cheaper Clyde
# Color Philadelphia
# Elephant Trojan
# Gleaming Jawbreaker
# Human Graffiti
# King Evolution
# Lady Stage
# Language Cowboy
# Mulholland Beast
# Oklahoma Jumanji
# Rules Human
# Splash Gump
# Vertigo Northwest
# Westward Seabiscuit
# Wizard Coldblooded

# %% [markdown]
# (19) What are the names of the films rented by the customer named Knight?  &nbsp; &nbsp; [`customer`, `rental`, `inventory`, `film`]

# %%
! sqlite3 sakila211.db "select title from customer join rental using (customer_id) join inventory using (inventory_id) join film using (film_id) where last_name='Knight'"
# Out:
# Jericho Mulan
# Frost Head
# Clerks Angels
# Wife Turn
# Expecations Natural
# Lawless Vision
# Soup Wisdom
# Heartbreakers Bright
# Bikini Borrowers
# Attacks Hate
# Cupboard Sinners
# Princess Giant
# Cyclone Family
# Platoon Instinct
# Knock Warlock
# Excitement Eve
# Right Cranes
# Hyde Doctor
# Fatal Haunted
# Chasing Fight
# Falcon Volume
# Tomorrow Hustler
# Half Outfield
# Horror Reign
# Borrowers Bedazzled

# %% [markdown]
# ## <span style="color:teal">Part 3: &nbsp; Monthly Report</span>

# %% [markdown]
# For this part of the project you will write a report generator that will print a summary of monthly activity for a customer.  The report should show a list of all the films rented during the month along with a total amount due.
# This example shows the activity for the customer named Leo Ebert for the month of June, 2005.
#
# <pre>
# --- Sakila DVD Rentals ---
#
# Monthly Report for Leo Ebert
#
# Lonely Elephant                 06/16/2005    $2.99
#                    ** late fee  06/24/2005    $2.99
# Enemy Odds                      06/18/2005    $4.99
#                    ** late fee  06/27/2005    $4.99
# Song Hedwig                     06/20/2005    $0.99
#                    ** late fee  06/26/2005    $0.99
# Wash Heavenly                   06/21/2005    $4.99
# Hurricane Affair                06/21/2005    $2.99
#
# Monthly Total:  $25.92
# </pre>
#
# To compute the total, the report generator needs to add up all the rental fees, and for any film returned late, add an additional rental fee as the late charge. In the example, Leo rented *Lonely Elephant* on June 16 but didn’t return it until June 24. It was a 3-day rental, so he was charged an additional \$2.99 (it was 5 days late, so we could have charged him \$4.98 in late fees, but we’ll keep it simple and just charge the basic fee as the late fee).
#
# We've broken the problem into separate parts so they can be implemented and tested separately.  Your job is to fill in the code cells so each part passes the auto-grader tests.
#
# **Note:** &nbsp; There is no documentation requirement for this project.

# %% [markdown]
# ### <span style="color:teal">Database Connection</span>

# %% [markdown]
# To simplify the code for this program you can define the database connection as a global variable.  The following code cell imports the libraries you need and defines the database connection.

# %%
from sqlite3 import connect

db = connect('sakila211.db')

# %% [markdown]
# ### <span style="color:teal">Dates</span>

# %% [markdown]
# Dates in a SQLite database are stored as strings.  The function below uses a Python library named `datetime` to parse a date string and return a string that can be printed as part of the report.  Read the online documentation for the `datetime` module if you want to learn more about date formats and functions that parse and format dates.
#
# **Note:** &nbsp; The format string is a global variable -- you can use this same format in your function that checks to see if a CD is overdue.

# %%
from datetime import datetime

date_format = "%Y-%m-%d %H:%M:%S.%f"

def mmddyyyy(date):
    d = datetime.strptime(date, date_format)
    return '{:02d}/{:02d}/{:02d}'.format(d.month, d.day, d.year)

# %%
assert mmddyyyy('2005-02-26 20:59:35.000') == '02/26/2005'

# %% [markdown]
# ### <span style="color:teal">Customer Name</span>

# %% [markdown]
# Fill in the definition of the `customer_name` function.  It will be passed a string with a last name, and it should return a list of tuples of the form `(first, last)` with the first and last names of all customers with the same last name.  If there are no customers with that name the list should be empty.

# %%
def customer_names(name):
    name=name.title()
    t=(name,)
    names=db.execute('select first_name, last_name from customer where last_name=?',  t)
    name_list=[]
    for row in names:
        name_list.append(row)
    return name_list

# %%
customer_names('turing')
# Out:
# []

# %% [markdown]
# ##### <span style="color:red">Autograder Tests:</span>

# %% [markdown]
# **Do not edit, copy, or delete these cells.**

# %%
assert customer_names('ebert') == [('Leo', 'Ebert')]

# %%
assert customer_names('smith') == [('Mary', 'Smith')]

# %%
assert customer_names('turing') == []

# %% [markdown]
# ### <span style="color:teal">Film List</span>

# %% [markdown]
# Fill in the body of the `film_list` function so it returns a list of all CDs rented by a customer during a specified month.
# The parameters that will be passed to the function are the customer's last name (a string) and the month and year (both integers).  Return a list of tuples that have the following values, in the order shown:
# * film title
# * rental rate (how much it costs to rent the CD)
# * rental date (the date the CD was rented)
# * return date (the date the CD was returned)
# * rental duration (the number of days the CD can be out before a late fee is charged)
#
# All of the information you need can be retrieved with a single query that joins the rental, inventory, film, and customer tables. Note that this is the same query used to answer Question 19 above, except with different column names.
#
# **Hint:** &nbsp; The dates in the database are strings.  Think about pattern matching when you write the WHERE clause that specifies the date range.

# %%
def film_list(name, month, year):
    if len(str(month))<2:
        month=str("0"+str(month))
    
    final_list=[]
    
    ## here's the pattern mathching
    d=("%{}-{}%".format(year,month),)
    
    #I could not get the database to narrow down the results for both
    #the time period and the last name I kept getting a multitude
    #of errors. I had to narrow time first
    #and write a loop to find the right people
    #below is my failed attemps to do it all in one step
    # Note: n=(name,)
    
    #work_list=db.execute ("select count() from customer join rental using(customer_id)join inventory using (inventory_id) join film where last_name=? and rental_date like ?",(n,d))
    
    
    
    
    work_list=db.execute ("select last_name, title, rental_rate, rental_date, return_date,rental_duration  from customer join rental using(customer_id)join inventory using (inventory_id) join film using (film_id) where rental_date like ?",(d))
    
    for item in work_list:
        if item[0]==name:
            final_list.append(item[1:])
    return final_list

# %% [markdown]
# ##### <span style="color:red">Autograder Tests:</span>

# %% [markdown]
# **Do not edit, copy, or delete these cells.**

# %%
leo = film_list('Ebert', 6, 2005)
assert len(leo) == 5
assert leo[0] == (('Lonely Elephant', 2.99, '2005-06-16 20:59:35.000', '2005-06-24 15:31:35.000', 3))

# %%
mary = film_list('Smith', 8, 2005)
assert len(mary) == 11
assert mary[0] == ('Adaptation Holes', 2.99, '2005-08-01 08:51:04.000', '2005-08-10 12:12:04.000', 7)

# %% [markdown]
# ### <span style="color:teal">Overdue CDs</span>

# %% [markdown]
# To decide whether a CD was returned late you need to subtract the rental date from the return date and see if the difference is greater than the rental duration. The easiest way to do this is to use Python’s `datetime` library.
#
# Using a call to `strptime` (see the body of the `mmddyyyy` function defined above) create `datetime` objects for the rental date and the return date. Then subtract the rental date from the return date to get a `timedelta` object:
# ```
#     diff = returned - rented
# ```
# Now you can get attributes of the object named `diff` to tell you how far apart the dates were, for example `diff.days` will tell you the time difference in days.
#
# Fill in the body of the `overdue` function.  The parameters are a rental date, a return date, and the rental duration.  Return TRUE if the CD was not returned or if the number of days it was checked out is greater than the rental duration.

# %%
from datetime import datetime
def overdue(rent_date, return_date, duration):
    date_format = "%Y-%m-%d %H:%M:%S.%f"

    rented= datetime.strptime(rent_date, date_format)
    returned=datetime.strptime(return_date, date_format)
    diff=returned-rented
    diff=diff.days
    if (diff>duration):
        return True

# %%
assert overdue('2005-06-16 20:59:35.000', '2005-06-19 20:59:35.000', 2)

# %%
assert not overdue('2005-06-16 20:59:35.000', '2005-06-17 20:59:35.000', 2)

# %%
assert not overdue('2005-06-16 20:59:35.000', '2005-06-19 20:59:34.000', 2)

# %% [markdown]
# ### <span style="color:teal">Report Generator</span>

# %% [markdown]
# Fill in the body of the function named `sakila_report` so it prints a monthly report.  The arguments passed to the function will be a customer's last name (a string) and a month and year (both integers).
#
# If the customer is not in the database, or if there are two customers with the same last name, return None.  Otherwise print a list of films and late fees and the total amount due.
#
# You can format the report however you would like, as long as the following items appear somewhere in the output:
# * every fee should be printed with a dollar sign and an amount, for example `$2.99` or `25.92`
# * the total amound due should be printed on a line that includes the word `"Total"` followed by a dollar amount on the same line

# %%
def sakila_report(customer, month, year):

    
    cust=customer_names(customer)
    Total=float(0)
   
   
    if cust!=[]:
        print("--- Sakila DVD Rentals ---")
        first_name,last_name=cust[0]
        print("Monthly Report For "+first_name+" "+last_name)
    
        data=film_list(last_name, month, year)
        for movie in data:
            print(str(movie[0])+"                   " +str(movie [2])+"    $"+str(movie[1]))
             
            Total+=movie[1]
            if overdue(movie[2], movie[3], movie[4]):
            
                print("                         ***Late Fee    "+ movie[3]+"   $"+str(movie[1]))
                Total+=movie[1]
        print("Monthly Total=   $"+str("{0:.2f}".format(Total)))

# %% [markdown]
# ##### <span style="color:red">Tests</span>

# %% [markdown]
# You can use code cells in this section (and add more if you wish) to test your functions.

# %%
sakila_report('Smith', 8, 2005)
# Out:
# --- Sakila DVD Rentals ---
# Monthly Report For Mary Smith
# Adaptation Holes                   2005-08-01 08:51:04.000    $2.99
#                          ***Late Fee    2005-08-10 12:12:04.000   $2.99
# Racer Egg                   2005-08-02 15:36:52.000    $2.99
#                          ***Late Fee    2005-08-10 16:40:52.000   $2.99
# Finding Anaconda                   2005-08-02 18:01:38.000    $0.99
# Minds Truman                   2005-08-17 12:37:54.000    $4.99
# Dalmations Sweden                   2005-08-18 03:57:29.000    $0.99
# Patient Sister                   2005-08-19 09:55:16.000    $0.99
# Jumanji Blade                   2005-08-19 13:56:54.000    $2.99
# Unforgiven Zoolander                   2005-08-21 23:33:57.000    $0.99
# Fireball Philadelphia                   2005-08-22 01:27:57.000    $0.99
#                          ***Late Fee    2005-08-27 07:01:57.000   $0.99
# Fireball Philadelphia                   2005-08-22 19:41:37.000    $0.99
#                          ***Late Fee    2005-08-28 22:49:37.000   $0.99
# Bikini Borrowers                   2005-08-22 20:03:46.000    $4.99
# Monthly Total=   $32.85

# %% [markdown]
# ##### <span style="color:red">Autograder Tests</span>

# %% [markdown]
# The tests for the `sakila_report` function will call the function and while using the IPython `capture` command to save everything the function prints.  We'll then use a function that counts the number of times a dollar amount (from either a rental fee or a late fee) occurs and make sure the total amount is the expected value.
#
# **Do not edit, copy, or delete these cells.**

# %%
import re

def check_report(text, expected_count, expected_total):
    nums = []
    for line in text.split('\n'):
        has_total = re.search(r'Total.*(\$\d+\.\d\d)', line)
        if has_total:
            assert has_total.group(1) == expected_total
        else:
            for s in re.findall(r'\$\d+\.\d\d', line):
                nums.append(s)
    assert(len(nums) == expected_count)
    total = 0.0
    for s in nums:
        total += float(s[1:])
    assert(round(total,2)) == round(float(expected_total[1:]), 2)
    return True

# %%
# %%capture res
sakila_report('Ebert', 6, 2005)

# %%
assert check_report(res.stdout, 8, '$25.92')

# %%
# %%capture res
sakila_report('Smith', 8, 2005)

# %%
assert check_report(res.stdout, 15, '$32.85')

# %%
# %%capture res
sakila_report('Turing', 6, 2005)

# %%
assert len(res.stdout) == 0
